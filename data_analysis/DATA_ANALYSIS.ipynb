# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import make_pipeline
import pickle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score

# %%
test_data = pd.read_csv('model_wrangling/wrangled_data.csv')

x_name = 'NSW_total'
y_name = 'YEAR'
x = np.array(test_data[x_name]).reshape(-1, 1)
y = np.array(test_data[y_name])

plt.figure(figsize=(10, 6))
plt.plot(test_data['YEAR'], test_data['NSW_total'], label='NSW Total', color='blue')
plt.xlabel('Date')
plt.ylabel('Total Value')
plt.title('NSW Total Over Time')
plt.legend()
plt.show()
