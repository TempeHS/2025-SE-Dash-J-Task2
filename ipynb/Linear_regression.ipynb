# %% [markdown]
# #### STEP 1
#
# import the required libraries for a linear regression model.

# %%
# Import frameworks
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('style_Matplotlib_charts.mplstyle')
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import make_pipeline
import pickle

# %% [markdown]
# #### STEP 2
#
#
# reading the wrangled training data

# %%
# Load the dataset
df = pd.read_csv('refined_trainingdata.csv')
# Show the first few rows of the dataframe
df.head()
# Out:
#          DATE   TOTAL  NSW_TOTAL  VIC_TOTAL  QLD_TOTAL  SA_TOTAL  WA_TOTAL  \
# 0  1998-12-01   994.4      198.0      229.6      440.3      35.4      66.6
# 1  1992-03-01  1000.4      276.1      236.6      322.7      66.8      57.8
# 2  2021-09-01   886.9      177.6      105.1      536.4      20.8      25.3
# 3  1992-06-01  1058.6      286.7      190.6      407.3      59.8      58.4
# 4  1988-03-01   951.3      265.6      198.0      305.0      80.9      59.8
#
#    TAS_TOTAL  DATE_NUMERIC  YEAR  MONTH
# 0       22.4        729724  1998     12
# 1       30.2        727258  1992      3
# 2       21.7        738034  2021      9
# 3       29.2        727350  1992      6
# 4       32.0        725797  1988      3

# %% [markdown]
# #### STEP 3
#
#
# creating the the graph based of columns

# %%
# Create a data frame from the csv file
training_data = pd.read_csv('refined_trainingdata.csv')

x_name = 'NSW_TOTAL'
y_name = 'YEAR'
x = np.array(training_data[x_name]).reshape(-1, 1)
y = np.array(training_data[y_name])

# %% [markdown]
# #### STEP 4
#
#
# ploting the linear regression model with training data.

# %%
# Plot the data points
plt.scatter(x, y, marker='x', c='r')
# Set the title
plt.title("Bulls")
# Set the y-axis label
plt.ylabel(f'Training {training_data[y_name].name}')
# Set the x-axis label
plt.xlabel(f'Training {training_data[x_name].name}')
plt.show()


# Create a pipeline with polynomial features and linear regression
degree = 2  # You can try different degrees
model = make_pipeline(PolynomialFeatures(degree), StandardScaler(), LinearRegression())

# %% [markdown]
# #### STEP 5
#
#
# creating the model

# %%
# Create the model
my_model = LinearRegression()
# Fit the model to the data
my_model.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# #### STEP 6
#
#
# creating a linear regression line of predicted values based of the training data

# %%
y_pred = my_model.predict(x)
plt.scatter(x, y_pred)
plt.scatter(x, y, marker='x', c='r')
plt.title("Diabetes Disease Progress")
plt.ylabel(f'Training {training_data[y_name].name}')
plt.xlabel(f'Training {training_data[x_name].name}')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_11926/29387704.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# save the model to disk
//filename = 'my_saved_model_v1.sav'
//pickle.dump(my_model, open('../2.4.Model_Testing_and_Validation/' + filename, 'wb'))
# Out:
#   Cell In[8], line 2
#     //filename = 'my_saved_model_v1.sav'
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### STEP 7
#
#
# now we need to do this for all data and not just the NSW_total

# %%
# Create a data frame from the csv file
training_data = pd.read_csv('refined_trainingdata.csv')

x_name = ['NSW_TOTAL','VIC_TOTAL','QLD_TOTAL','SA_TOTAL','WA_TOTAL','TAS_TOTAL'] #input multiple types of data, even new ones e.g BGU
y_name = 'YEAR'
x = np.array(training_data[x_name])
y = np.array(training_data[y_name])

# %%
# plot predictions and targets vs original features    
fig,ax=plt.subplots(1,len(x_name),figsize=(12,3),sharey=True)
for i in range(len(ax)):
    ax[i].scatter(x[:,i],y, label = 'YEAR')
    ax[i].set_xlabel(x_name[i])
ax[0].set_ylabel("YEAR"); ax[0].legend();
fig.suptitle("Year Vs Number of animals")
plt.show()

# %%
# Create the model
my_model = LinearRegression()
# Fit the model to the data
my_model.fit(x, y)
# Out:
# LinearRegression()

# %%
# scatter plot predictions and targets vs original features    
y_pred = my_model.predict(x)
fig,ax=plt.subplots(1,len(x_name),figsize=(12,3),sharey=True)
for i in range(len(ax)):
    ax[i].scatter(x[:,i],y, label = 'year')
    ax[i].set_xlabel(x_name[i])
    ax[i].scatter(x[:,i],y_pred,color="orange", label = 'predict')
ax[0].set_ylabel("year"); ax[0].legend();
fig.suptitle("Year Vs Number of animals")
plt.show()

# %%
# save the model to disk
filename = 'my_saved_model_v2.sav'
pickle.dump(my_model, open('../2.4.Model_Testing_and_Validation/' + filename, 'wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # save the model to disk
#       2 filename = 'my_saved_model_v2.sav'
# ----> 3 pickle.dump(my_model, open('../2.4.Model_Testing_and_Validation/' + filename, 'wb'))
#
# NameError: name 'pickle' is not defined
